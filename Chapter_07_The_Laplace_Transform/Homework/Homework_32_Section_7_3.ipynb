# %% [markdown]
# # Homework 32 — Section 7.3
# ## Operational Properties I

# %% [markdown]
# > **Student homework notebook — Section 7.3**
# >
# > Work the analytical parts before running code. Code cells marked `TODO` are intentionally incomplete for you to finish.
# > This repository contains **no homework solution notebooks**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.integrate import quad, solve_ivp
from scipy.signal import fftconvolve
from scipy.linalg import expm
from IPython.display import display, Markdown

try:
    from ipywidgets import interact, FloatSlider, IntSlider, Dropdown
    WIDGETS_AVAILABLE = True
except ImportError:
    WIDGETS_AVAILABLE = False

plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["axes.grid"] = True
np.set_printoptions(precision=6, suppress=True)

def unit_step(t, a=0.0):
    t = np.asarray(t)
    return (t >= a).astype(float)

print("Notebook ready.")
print("Interactive widgets available:", WIDGETS_AVAILABLE)

# %% [markdown]
# ## Problem 1
# Find $\mathcal L\{e^{-2t}\sin 5t\}$ and $\mathcal L^{-1}\{(s-3)/[(s-3)^2+16]\}$.

# %% [markdown]
# ## Problem 2
# Rewrite as unit-step expressions:
# 1. $f(t)=0$ for $t<2$ and $f(t)=t-2$ for $t\ge2$.
# 2. $g(t)=t$ for $t<3$ and $g(t)=6-t$ for $t\ge3$.

# %% [markdown]
# ## Problem 3
# Find the transform of
# $$
# u(t-4)(t-4)^2.
# $$

# %% [markdown]
# ## Problem 4
# Find the inverse transform of
# $$
# e^{-2s}\frac{s}{s^2+9}.
# $$

# %% [markdown]
# ## Problem 5
# Solve
# $$
# y'+y=u(t-3),\quad y(0)=0.
# $$
# Graph the forcing and response.

# %%
# TODO: derive, invert, and graph.

# %% [markdown]
# ## Reflection
# Why must the delayed factor be written as a function of $t-a$ rather than simply as a function of $t$?
