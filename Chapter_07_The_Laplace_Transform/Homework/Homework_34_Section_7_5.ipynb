# %% [markdown]
# # Homework 34 — Section 7.5
# ## The Dirac Delta Function

# %% [markdown]
# > **Student homework notebook — Section 7.5**
# >
# > Work the analytical parts before running code. Code cells marked `TODO` are intentionally incomplete for you to finish.
# > This repository contains **no homework solution notebooks**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.integrate import quad, solve_ivp
from scipy.signal import fftconvolve
from scipy.linalg import expm, eig
from IPython.display import display, Markdown

try:
    from ipywidgets import interact, FloatSlider, IntSlider, Dropdown
    WIDGETS_AVAILABLE = True
except ImportError:
    WIDGETS_AVAILABLE = False

plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["axes.grid"] = True
np.set_printoptions(precision=6, suppress=True)

def unit_step(t, a=0.0):
    t = np.asarray(t)
    return (t >= a).astype(float)

print("Notebook ready.")
print("Interactive widgets available:", WIDGETS_AVAILABLE)

# %% [markdown]
# ## Problem 1
# Construct a rectangular pulse centered at $t=2$ with width $0.1$ and area $3$. State its height.

# %% [markdown]
# ## Problem 2
# Use the sampling property to evaluate
# $$
# \int_0^\infty e^{-2t}\sin t\,\delta(t-4)\,dt.
# $$

# %% [markdown]
# ## Problem 3
# Find the Laplace transform of $5\delta(t-3)$.

# %% [markdown]
# ## Problem 4
# Solve
# $$
# y''+9y=2\delta(t-2),\quad y(0)=y'(0)=0.
# $$

# %% [markdown]
# ## Problem 5
# For
# $$
# 4y''+y=\delta(t-5),
# $$
# derive the jump in $y'$ across $t=5$ and verify it from the explicit solution.

# %%
# TODO: derive and plot displacement and velocity.

# %% [markdown]
# ## Reflection
# Why is impulse better interpreted by its area than by its height?
