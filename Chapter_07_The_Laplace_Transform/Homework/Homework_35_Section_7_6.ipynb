# %% [markdown]
# # Homework 35 — Section 7.6
# ## Systems of Linear Differential Equations

# %% [markdown]
# > **Student homework notebook — Section 7.6**
# >
# > Work the analytical parts before running code. Code cells marked `TODO` are intentionally incomplete for you to finish.
# > This repository contains **no homework solution notebooks**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.integrate import quad, solve_ivp
from scipy.signal import fftconvolve
from scipy.linalg import expm, eig
from IPython.display import display, Markdown

try:
    from ipywidgets import interact, FloatSlider, IntSlider, Dropdown
    WIDGETS_AVAILABLE = True
except ImportError:
    WIDGETS_AVAILABLE = False

plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["axes.grid"] = True
np.set_printoptions(precision=6, suppress=True)

def unit_step(t, a=0.0):
    t = np.asarray(t)
    return (t >= a).astype(float)

print("Notebook ready.")
print("Interactive widgets available:", WIDGETS_AVAILABLE)

# %% [markdown]
# ## Problem 1
# Transform
# $$
# x'=2x-y,\qquad y'=x-3y,
# $$
# with $x(0)=1$, $y(0)=0$, into algebraic equations for $X(s)$ and $Y(s)$.

# %% [markdown]
# ## Problem 2
# Solve the system in Problem 1 using Laplace transforms.

# %% [markdown]
# ## Problem 3
# For $m_1=m_2=1$, $k_1=3$, $k_2=2$, compute the two natural frequencies and mode shapes.

# %% [markdown]
# ## Problem 4
# Simulate the coupled-spring system from $(x_1,x_2,x_1',x_2')=(1,0,0,0)$ and plot both displacements.

# %%
# TODO: formulate the four-dimensional first-order system.

# %% [markdown]
# ## Problem 5
# For
# $$
# \mathbf i'=
# \begin{pmatrix}-2&1\\1&-2\end{pmatrix}\mathbf i+
# \begin{pmatrix}1\\0\end{pmatrix}5,
# \quad \mathbf i(0)=0,
# $$
# find the steady state and simulate the transient.

# %% [markdown]
# ## Reflection
# What does an eigenvector mean physically in a coupled mechanical system?
