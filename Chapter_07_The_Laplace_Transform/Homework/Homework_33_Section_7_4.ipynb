# %% [markdown]
# # Homework 33 — Section 7.4
# ## Operational Properties II

# %% [markdown]
# > **Student homework notebook — Section 7.4**
# >
# > Work the analytical parts before running code. Code cells marked `TODO` are intentionally incomplete for you to finish.
# > This repository contains **no homework solution notebooks**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.integrate import quad, solve_ivp
from scipy.signal import fftconvolve
from scipy.linalg import expm
from IPython.display import display, Markdown

try:
    from ipywidgets import interact, FloatSlider, IntSlider, Dropdown
    WIDGETS_AVAILABLE = True
except ImportError:
    WIDGETS_AVAILABLE = False

plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["axes.grid"] = True
np.set_printoptions(precision=6, suppress=True)

def unit_step(t, a=0.0):
    t = np.asarray(t)
    return (t >= a).astype(float)

print("Notebook ready.")
print("Interactive widgets available:", WIDGETS_AVAILABLE)

# %% [markdown]
# ## Problem 1
# Use transform differentiation to find $\mathcal L\{t e^{-2t}\}$ and $\mathcal L\{t\sin 4t\}$.

# %% [markdown]
# ## Problem 2
# Compute directly:
# $$
# (1*e^{-t})(t).
# $$

# %% [markdown]
# ## Problem 3
# Use convolution to invert
# $$
# \frac{1}{s(s^2+4)}.
# $$

# %% [markdown]
# ## Problem 4
# Solve the Volterra equation
# $$
# f(t)=t+\int_0^t f(\tau)\,d\tau.
# $$

# %% [markdown]
# ## Problem 5
# Find the transform of the periodic function of period $3$ defined by $f(t)=t$ on $0\le t<3$.

# %%
# TODO: apply the periodic-transform formula.

# %% [markdown]
# ## Reflection
# What is the physical interpretation of convolution in a linear input-output system?
