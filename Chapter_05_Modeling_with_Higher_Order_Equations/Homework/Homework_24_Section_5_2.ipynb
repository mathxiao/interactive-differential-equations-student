# %% [markdown]
# # Homework 24 — Section 5.2
# ## Linear Boundary-Value Models

# %% [markdown]
# > **Student homework notebook — Section 5.2**
# >
# > Work the analytical parts before running code. Code cells marked `TODO` are intentionally incomplete for you to finish.
# > This repository contains **no homework solution notebooks**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.integrate import solve_ivp, quad
from scipy.optimize import brentq
from IPython.display import display, Markdown

try:
    from ipywidgets import interact, FloatSlider, IntSlider, Dropdown
    WIDGETS_AVAILABLE = True
except ImportError:
    WIDGETS_AVAILABLE = False

plt.rcParams['figure.figsize'] = (8, 5)
plt.rcParams['axes.grid'] = True
np.set_printoptions(precision=6, suppress=True)

def solve_second_order(accel, t_span, y0, points=1000, **kwargs):
    def rhs(t, z):
        x, v = z
        return [v, accel(t, x, v)]
    t_eval = np.linspace(t_span[0], t_span[1], points)
    return solve_ivp(rhs, t_span, y0, t_eval=t_eval, **kwargs)

print('Notebook ready.')
print('Interactive widgets available:', WIDGETS_AVAILABLE)

# %% [markdown]
# ## Problem 1 — Boundary-condition dictionary
#
# State the two boundary conditions at an endpoint that is:
#
# 1. clamped;
# 2. free;
# 3. simply supported.
#
# Explain the physical meaning of each condition.

# %% [markdown]
# ## Problem 2 — Clamped beam
#
# A beam of length $L=5$ has $EI=200$ and uniform downward load $w_0=6$.
#
# 1. Write the BVP.
# 2. Use the formula for a clamped–clamped beam.
# 3. Find the midpoint deflection.
# 4. Plot deflection, slope, moment, and shear.

# %% [markdown]
# ## Problem 3 — Simply supported beam
#
# Verify that
#
# $$
# y(x)=\frac{w_0x}{24EI}(L^3-2Lx^2+x^3)
# $$
#
# solves the uniform-load BVP with
#
# $$
# y(0)=y(L)=y''(0)=y''(L)=0.
# $$
#
# Find the maximum deflection numerically.

# %%
# TODO: use SymPy for verification and numerical optimization or a dense grid for the maximum.

# %% [markdown]
# ## Problem 4 — Eigenvalues
#
# Solve
#
# $$
# y''+\lambda y=0,
# \qquad y(0)=0,
# \qquad y(2)=0.
# $$
#
# List the first five eigenvalues and plot the corresponding eigenfunctions.

# %% [markdown]
# ## Problem 5 — Orthogonality
#
# Numerically evaluate
#
# $$
# \int_0^2\sin\left(\frac{m\pi x}{2}\right)
# \sin\left(\frac{n\pi x}{2}\right)dx
# $$
#
# for $1\le m,n\le5$. Display the result as a matrix and explain the diagonal structure.

# %% [markdown]
# ## Problem 6 — Euler buckling
#
# A pin-ended column has $EI=3.2\times10^5$ N m$^2$ and length $L=4$ m.
#
# 1. Find the first three critical loads.
# 2. Plot the first three buckling modes.
# 3. Explain why the first load is the most important in design.

# %% [markdown]
# ## Reflection
#
# Why can an IVP have a unique solution while a related BVP can have one, infinitely many, or no solutions?
