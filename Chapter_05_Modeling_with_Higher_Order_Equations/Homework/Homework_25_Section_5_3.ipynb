# %% [markdown]
# # Homework 25 — Section 5.3
# ## Nonlinear Models

# %% [markdown]
# > **Student homework notebook — Section 5.3**
# >
# > Work the analytical parts before running code. Code cells marked `TODO` are intentionally incomplete for you to finish.
# > This repository contains **no homework solution notebooks**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.integrate import solve_ivp, quad
from scipy.optimize import brentq
from IPython.display import display, Markdown

try:
    from ipywidgets import interact, FloatSlider, IntSlider, Dropdown
    WIDGETS_AVAILABLE = True
except ImportError:
    WIDGETS_AVAILABLE = False

plt.rcParams['figure.figsize'] = (8, 5)
plt.rcParams['axes.grid'] = True
np.set_printoptions(precision=6, suppress=True)

def solve_second_order(accel, t_span, y0, points=1000, **kwargs):
    def rhs(t, z):
        x, v = z
        return [v, accel(t, x, v)]
    t_eval = np.linspace(t_span[0], t_span[1], points)
    return solve_ivp(rhs, t_span, y0, t_eval=t_eval, **kwargs)

print('Notebook ready.')
print('Interactive widgets available:', WIDGETS_AVAILABLE)

# %% [markdown]
# ## Problem 1 — Restoring force and potential
#
# For
#
# $$
# x''+2x+\alpha x^3=0,
# $$
#
# 1. find the potential energy;
# 2. graph the restoring law and potential for $\alpha=0.5$ and $\alpha=-0.2$;
# 3. state a physically reasonable displacement restriction in the softening case.

# %% [markdown]
# ## Problem 2 — Nonlinear period
#
# For $x''+x+0.5x^3=0$ with $x'(0)=0$, numerically estimate the period for initial amplitudes $0.25$, $0.75$, $1.25$, and $1.75$. Compare with $2\pi$.

# %%
# TODO: simulate and detect repeated zero crossings or repeated maxima.

# %% [markdown]
# ## Problem 3 — Pendulum linearization
#
# For $\ell=1$ m and $g=9.81$ m/s$^2$, compare the nonlinear and small-angle solutions for initial angles $0.2$, $1.0$, and $2.5$ radians, all released from rest.
#
# 1. Plot each comparison.
# 2. Estimate the period error.
# 3. Explain why the linear model deteriorates.

# %% [markdown]
# ## Problem 4 — Pendulum energy threshold
#
# For a pendulum with $\ell=1$ and initial angle $\theta_0=0.6$, find the initial angular velocity that lies exactly on the separatrix. Simulate a value 5% below and 5% above the threshold.

# %% [markdown]
# ## Problem 5 — Catenary
#
# A cable is modeled by
#
# $$
# y''=0.4\sqrt{1+(y')^2},
# \qquad y(0)=2,
# \qquad y'(0)=0.
# $$
#
# 1. Find the exact catenary.
# 2. Verify it symbolically.
# 3. Compare it with the quadratic approximation near $x=0$.

# %% [markdown]
# ## Problem 6 — Escape velocity
#
# In nondimensional units, let $\mu=1$ and launch radius $R=1$.
#
# 1. Find escape speed.
# 2. Simulate speed ratios $0.8$, $1.0$, and $1.2$.
# 3. Compare the energy classification with the numerical trajectory.

# %% [markdown]
# ## Reflection
#
# Why is a numerical graph alone insufficient evidence that all solutions of a nonlinear differential equation have the same qualitative behavior?
