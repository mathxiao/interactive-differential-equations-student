# %% [markdown]
# # Homework 23 — Section 5.1
# ## Linear Initial-Value Models
#
# For each physical problem, define the positive direction, state units, formulate the IVP, and interpret the result.

# %% [markdown]
# > **Student homework notebook — Section 5.1**
# >
# > Work the analytical parts before running code. Code cells marked `TODO` are intentionally incomplete for you to finish.
# > This repository contains **no homework solution notebooks**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.integrate import solve_ivp, quad
from scipy.optimize import brentq
from IPython.display import display, Markdown

try:
    from ipywidgets import interact, FloatSlider, IntSlider, Dropdown
    WIDGETS_AVAILABLE = True
except ImportError:
    WIDGETS_AVAILABLE = False

plt.rcParams['figure.figsize'] = (8, 5)
plt.rcParams['axes.grid'] = True
np.set_printoptions(precision=6, suppress=True)

def solve_second_order(accel, t_span, y0, points=1000, **kwargs):
    def rhs(t, z):
        x, v = z
        return [v, accel(t, x, v)]
    t_eval = np.linspace(t_span[0], t_span[1], points)
    return solve_ivp(rhs, t_span, y0, t_eval=t_eval, **kwargs)

print('Notebook ready.')
print('Interactive widgets available:', WIDGETS_AVAILABLE)

# %% [markdown]
# ## Problem 1 — Free undamped motion
#
# A $3$-kg mass is attached to a spring with stiffness $48$ N/m. It is displaced $0.25$ m below equilibrium and released with upward velocity $0.8$ m/s.
#
# 1. Formulate the IVP.
# 2. Find the equation of motion.
# 3. Find amplitude, phase, period, and frequency.
# 4. Plot displacement and phase portrait.

# %% [markdown]
# ## Problem 2 — Effective springs
#
# Two springs have $k_1=12$ N/m and $k_2=20$ N/m. A $2$-kg mass is attached first to the springs in parallel and then to them in series.
#
# 1. Find both effective stiffnesses.
# 2. Find both natural periods.
# 3. Simulate one normalized oscillation for each system.

# %% [markdown]
# ## Problem 3 — Damping classification
#
# For each system, classify the motion and solve the IVP $x(0)=1$, $x'(0)=0$.
#
# 1. $x''+3x'+2x=0$
# 2. $x''+4x'+4x=0$
# 3. $x''+2x'+9x=0$

# %% [markdown]
# ## Problem 4 — Energy loss
#
# For
#
# $$
# x''+1.5x'+9x=0,
# \qquad x(0)=1,
# \qquad x'(0)=0,
# $$
#
# simulate the solution and verify numerically that
#
# $$
# E'= -1.5(x')^2.
# $$

# %%
# TODO: solve the system and compare a numerical derivative of E with -1.5 v^2.

# %% [markdown]
# ## Problem 5 — Forced oscillator
#
# For
#
# $$
# x''+0.8x'+16x=6\cos(\gamma t),
# $$
#
# 1. derive the steady-state amplitude $A(\gamma)$;
# 2. graph $A(\gamma)$ for $0<\gamma<8$;
# 3. estimate the frequency giving the largest amplitude;
# 4. compare responses for $\gamma=2$, $4$, and $6$.

# %% [markdown]
# ## Problem 6 — LRC circuit
#
# An LRC circuit has $L=0.4$ H, $R=5$ ohms, $C=0.025$ F, and voltage $E(t)=12\sin(\gamma t)$.
#
# 1. Write the charge equation.
# 2. Find the undamped resonant frequency.
# 3. Plot the current-amplitude response.
# 4. Explain the roles of reactance and impedance.

# %% [markdown]
# ## Reflection
#
# Identify one assumption in the ideal spring, damping, or LRC model that could fail in an experiment. Describe a corresponding model modification.
