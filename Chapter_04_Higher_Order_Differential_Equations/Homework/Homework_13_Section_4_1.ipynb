# %% [markdown]
# # Homework 13 — Section 4.1
# ## Theory of Linear Equations
#
# State the theorem or definition used in each justification.

# %% [markdown]
# > **Student homework notebook — Section 4.1**
# >
# > Work the analytical parts before running code. Code cells marked `TODO` are intentionally incomplete for you to finish.
# > This repository contains **no homework solution notebooks**.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.integrate import solve_ivp, quad
from scipy.linalg import expm
from IPython.display import display, Markdown
try:
    from ipywidgets import interact, FloatSlider, IntSlider, Dropdown
    WIDGETS_AVAILABLE=True
except ImportError:
    WIDGETS_AVAILABLE=False

if os.environ.get('NB_VALIDATION_MODE') == '1':
    WIDGETS_AVAILABLE=False
plt.rcParams['figure.figsize']=(8,5)
plt.rcParams['axes.grid']=True
np.set_printoptions(precision=6,suppress=True)

def solve_second_order(f, span, y0, yp0, points=900, **kwargs):
    def rhs(x,z): return [z[1], f(x,z[0],z[1])]
    t=np.linspace(span[0],span[1],points)
    return solve_ivp(rhs,span,[y0,yp0],t_eval=t,**kwargs)

def wronskian_symbolic(funcs,x):
    return sp.simplify(sp.Matrix([[sp.diff(f,x,j) for f in funcs] for j in range(len(funcs))]).det())

print('Notebook ready.')
print('Interactive widgets available:',WIDGETS_AVAILABLE)

# %% [markdown]
# ## Problem 1 — Existence and uniqueness
# For
# $$
# (x-2)y''+\sin x\,y'+e^xy=\ln(1+x^2),
# $$
# identify maximal intervals on which an IVP has a unique solution.

# %% [markdown]
# ## Problem 2 — BVP outcomes
# For $y''+9y=0$ with $y(0)=0$, classify the BVP as one, many, or no solutions for:
# 1. $y(\pi/3)=0$; 2. $y(\pi/6)=0$; 3. $y(\pi/3)=2$. Plot representative results.

# %% [markdown]
# ## Problem 3 — Wronskians
# Compute the Wronskian and classify: (a) $e^x,e^{-x}$; (b) $\cos x,\sin x$; (c) $1,x,2+x$.

# %% [markdown]
# ## Problem 4 — Fundamental set
# Verify that $1,e^x,e^{-x}$ is a fundamental set for $y^{(3)}-y'=0$ and write the general solution.

# %% [markdown]
# ## Problem 5 — Superposition
# If $L[y_1]=x$ and $L[y_2]=e^x$, what forcing corresponds to $3y_1-2y_2$? Explain.

# %% [markdown]
# ## Problem 6 — Complementary plus particular
# Verify that $y_p=x^2/2$ is a particular solution of $y''=1$, then write the general solution and apply $y(0)=1,y'(0)=-2$.
