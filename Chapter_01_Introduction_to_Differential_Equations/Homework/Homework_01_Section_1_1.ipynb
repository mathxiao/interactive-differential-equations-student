# %% [markdown]
# # Homework 1 — Section 1.1
# ## Definitions, Classification, and Solutions
#
# **Student notebook**
#
# ### Instructions
#
# - Show the mathematical reasoning in Markdown cells or on separate paper, as directed by your instructor.
# - Run every computational cell.
# - Replace each `TODO` with your own work.
# - Interpret every graph in words; a graph alone is not a complete answer.

# %% [markdown]
# > **Student homework notebook — Section 1.1**
# >
# > Work the analytical parts before running code. Code cells marked `TODO` are intentionally incomplete for you to finish.
# > This repository contains **no homework solution notebooks**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from IPython.display import display
from scipy.integrate import solve_ivp

try:
    from ipywidgets import interact, FloatSlider, IntSlider
    WIDGETS_AVAILABLE = True
except ImportError:
    WIDGETS_AVAILABLE = False

plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["axes.grid"] = True
np.set_printoptions(precision=4, suppress=True)

print("Notebook ready.")
print("Interactive widgets available:", WIDGETS_AVAILABLE)

# %% [markdown]
# ## Problem 1 — Classification
#
# For each equation, state:
#
# - ODE or PDE,
# - order,
# - linear or nonlinear.
#
# 1. $y''-4xy'+7y=\cos x$
# 2. $y'+y^2=x$
# 3. $u_t=5u_{xx}$
# 4. $x\,y'''+(y')^2=0$
# 5. $t^2z''+tz'-z=0$
#
# Write your answers in the table below.
#
# | Equation | ODE/PDE | Order | Linear/Nonlinear |
# |---|---|---:|---|
# | 1 | TODO | TODO | TODO |
# | 2 | TODO | TODO | TODO |
# | 3 | TODO | TODO | TODO |
# | 4 | TODO | TODO | TODO |
# | 5 | TODO | TODO | TODO |

# %% [markdown]
# ## Problem 2 — Equivalent forms
#
# Rewrite
#
# $$
# (3x+y)\,dx+(x-2)\,dy=0
# $$
#
# in normal form $y'=f(x,y)$. State where this normal form is defined.

# %% [markdown]
# <details>
# <summary><strong>Hint</strong></summary>
#
# Use $dy=y' dx$, collect the terms, and divide by the coefficient of $y'$.
#
# </details>

# %% [markdown]
# ## Problem 3 — Verify a solution
#
# Verify directly that
#
# $$
# y=2e^{-x}+x-1
# $$
#
# solves
#
# $$
# y'+y=x.
# $$
#
# Use SymPy to confirm your hand calculation.

# %%
x = sp.symbols("x", real=True)

# TODO: enter the proposed solution.
y = 0

# TODO: compute y' + y - x.
residual = sp.simplify(0)

print("Residual:")
display(residual)

# %% [markdown]
# ## Problem 4 — Interval of definition
#
# Show that
#
# $$
# y=\frac{1}{x+1}
# $$
#
# solves
#
# $$
# (x+1)y'+y=0.
# $$
#
# Identify both maximal intervals on which this formula defines a solution.

# %% [markdown]
# ## Problem 5 — Implicit solution
#
# The curve
#
# $$
# x^2+2y^2=18
# $$
#
# is an implicit solution of a first-order equation.
#
# 1. Differentiate implicitly and solve for $y'$.
# 2. Determine where the normal form is undefined.
# 3. Plot both branches using the code cell below.

# %%
# TODO: choose a suitable grid for x.
x_vals = np.linspace(-1, 1, 20)

# TODO: calculate the upper and lower branches.
y_upper = np.zeros_like(x_vals)
y_lower = np.zeros_like(x_vals)

plt.plot(x_vals, y_upper, label="upper branch")
plt.plot(x_vals, y_lower, label="lower branch")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Implicit solution branches")
plt.legend()
plt.show()

# %% [markdown]
# ## Problem 6 — Explore a solution family
#
# The family
#
# $$
# y=Ce^{-x}+x-1
# $$
#
# solves $y'+y=x$.
#
# 1. Plot the curves for $C=-4,-2,0,2,4$.
# 2. Which value of $C$ gives a curve passing through $(0,3)$?
# 3. Highlight that curve.

# %%
x_vals = np.linspace(-1, 4, 500)
C_values = [-4, -2, 0, 2, 4]

# TODO: plot the family.
for C in C_values:
    pass

# TODO: plot the selected curve with a different line style and larger width.

plt.xlabel("x")
plt.ylabel("y")
plt.title("A one-parameter family")
plt.legend()
plt.show()

# %% [markdown]
# ## Problem 7 — Singular solution
#
# Verify that both
#
# $$
# y=(x-C)^3
# \qquad\text{and}\qquad
# y=0
# $$
#
# solve
#
# $$
# y'=3y^{2/3}.
# $$
#
# Explain why $y=0$ is not obtained by selecting a finite value of $C$.

# %% [markdown]
# ## Computational reflection
#
# In 3–5 sentences, explain how a differential equation, a family of solution curves, and an initial condition play different roles.
