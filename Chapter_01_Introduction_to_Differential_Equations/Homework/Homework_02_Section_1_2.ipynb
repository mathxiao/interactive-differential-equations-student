# %% [markdown]
# # Homework 2 — Section 1.2
# ## Initial-Value Problems, Existence, and Uniqueness
#
# **Student notebook**

# %% [markdown]
# > **Student homework notebook — Section 1.2**
# >
# > Work the analytical parts before running code. Code cells marked `TODO` are intentionally incomplete for you to finish.
# > This repository contains **no homework solution notebooks**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from IPython.display import display
from scipy.integrate import solve_ivp

try:
    from ipywidgets import interact, FloatSlider, IntSlider
    WIDGETS_AVAILABLE = True
except ImportError:
    WIDGETS_AVAILABLE = False

plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["axes.grid"] = True
np.set_printoptions(precision=4, suppress=True)

print("Notebook ready.")
print("Interactive widgets available:", WIDGETS_AVAILABLE)

# %% [markdown]
# ## Problem 1 — First-order IVP
#
# The family
#
# $$
# y=Ce^{-3x}
# $$
#
# solves $y'=-3y$. Find the particular solution satisfying
#
# $$
# y(2)=5.
# $$
#
# Plot the solution on $0\le x\le4$.

# %%
x_vals = np.linspace(0, 4, 400)

# TODO: calculate C.
C = 0

# TODO: calculate y values.
y_vals = np.zeros_like(x_vals)

plt.plot(x_vals, y_vals)
plt.scatter([2], [5], s=70)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Problem 1")
plt.show()

# %% [markdown]
# ## Problem 2 — Second-order IVP
#
# The family
#
# $$
# x(t)=c_1\cos(3t)+c_2\sin(3t)
# $$
#
# solves $x''+9x=0$. Find the solution satisfying
#
# $$
# x(0)=-2,\qquad x'(0)=6.
# $$
#
# Plot the position and velocity for $0\le t\le 2\pi$.

# %%
t = np.linspace(0, 2*np.pi, 600)

# TODO: enter c1 and c2.
c1 = 0
c2 = 0

position = c1*np.cos(3*t) + c2*np.sin(3*t)
velocity = -3*c1*np.sin(3*t) + 3*c2*np.cos(3*t)

plt.plot(t, position, label="position")
plt.plot(t, velocity, linestyle="--", label="velocity")
plt.xlabel("t")
plt.legend()
plt.show()

# %% [markdown]
# ## Problem 3 — Existence and uniqueness region
#
# For
#
# $$
# y'=\frac{x+1}{y-2},\qquad y(0)=0,
# $$
#
# 1. Find $f_y$.
# 2. Identify where $f$ and $f_y$ are discontinuous.
# 3. Choose a rectangle containing $(0,0)$ on which the standard theorem applies.
# 4. Explain why your rectangle must not cross $y=2$.

# %% [markdown]
# <details>
# <summary><strong>Hint</strong></summary>
#
# A simple choice is a rectangle with vertical range strictly below $y=2$.
#
# </details>

# %% [markdown]
# ## Problem 4 — Nonuniqueness
#
# Verify that both $y=0$ and $y=x^3$ solve
#
# $$
# y'=3y^{2/3},\qquad y(0)=0.
# $$
#
# Then create and plot a third solution that remains zero until $x=1$ and then departs.

# %%
x_vals = np.linspace(-1, 3, 600)

# TODO: construct the waiting-time solution.
y_wait = np.zeros_like(x_vals)

plt.plot(x_vals, y_wait, label="your waiting-time solution")
plt.scatter([0], [0], s=70)
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

# %% [markdown]
# ## Problem 5 — Maximal interval
#
# Solve
#
# $$
# y'=y^2,\qquad y(0)=-2.
# $$
#
# 1. Find the exact solution.
# 2. Find its vertical asymptote.
# 3. State the maximal interval containing $x=0$.
# 4. Plot the exact solution.

# %%
x_vals = np.linspace(-2, 4, 600)

# TODO: avoid evaluating exactly at the singular point.
# Plot the solution on both sides if appropriate.

plt.xlabel("x")
plt.ylabel("y")
plt.ylim(-10, 10)
plt.title("Problem 5")
plt.show()

# %% [markdown]
# ## Problem 6 — Numerical verification
#
# Use `solve_ivp` to approximate
#
# $$
# y'=y^2,\qquad y(0)=-2
# $$
#
# on a safe interval contained in the maximal interval. Compare the numerical and exact solutions and report the maximum absolute error on your grid.

# %%
def rhs(x, y):
    return y**2

# TODO: choose a safe t_span and t_eval.
t_span = (0, 1)
t_eval = np.linspace(*t_span, 100)

# TODO: call solve_ivp and construct the exact solution.
# sol = ...
# exact = ...
# error = ...

print("Maximum absolute error: TODO")

# %% [markdown]
# ## Reflection
#
# Why can a theorem guarantee a unique solution near the initial point without guaranteeing a solution for all future time?
