# %% [markdown]
# # Homework 11 — Section 3.2
# ## Nonlinear Models

# %% [markdown]
# > **Student homework notebook — Section 3.2**
# >
# > Work the analytical parts before running code. Code cells marked `TODO` are intentionally incomplete for you to finish.
# > This repository contains **no homework solution notebooks**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.integrate import solve_ivp
from scipy.optimize import brentq
from matplotlib.patches import Rectangle, FancyArrowPatch, Circle
from IPython.display import display, Markdown

try:
    from ipywidgets import interact, FloatSlider, IntSlider, Dropdown
    WIDGETS_AVAILABLE = True
except ImportError:
    WIDGETS_AVAILABLE = False

plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["axes.grid"] = True
np.set_printoptions(precision=5, suppress=True)

def safe_solve(rhs, t_span, y0, points=700, **kwargs):
    t_eval = np.linspace(t_span[0], t_span[1], points)
    return solve_ivp(rhs, t_span, y0, t_eval=t_eval, **kwargs)

print("Notebook ready.")
print("Interactive widgets available:", WIDGETS_AVAILABLE)

# %% [markdown]
# ## Problem 1 — Logistic solution
#
# A population satisfies
#
# $$
# P'=0.3P\left(1-\frac{P}{1500}\right),
# \qquad
# P(0)=75.
# $$
#
# 1. Find the explicit solution.
# 2. Determine when $P=750$.
# 3. Find the maximum growth rate.
# 4. Plot $P(t)$ and $P'(t)$.

# %% [markdown]
# ## Problem 2 — Initial value above carrying capacity
#
# Use the same logistic model but with $P(0)=1800$.
#
# 1. Predict the direction of change without solving.
# 2. Plot the solution.
# 3. Determine the long-term limit.
# 4. Explain why the curve has no future inflection point.

# %% [markdown]
# ## Problem 3 — Estimate a logistic parameter
#
# A population has $K=2000$, $P(0)=100$, and $P(6)=500$.
#
# Estimate $r$ and predict $P(12)$.

# %% [markdown]
# ## Problem 4 — Constant harvesting
#
# For
#
# $$
# P'=0.4P\left(1-\frac{P}{1000}\right)-h,
# $$
#
# analyze $h=60$, $h=100$, and $h=120$.
#
# For each value:
#
# 1. find all nonnegative equilibria;
# 2. classify their stability;
# 3. simulate solutions from several initial populations;
# 4. interpret the management risk.

# %%
# TODO: create phase-rate plots and time simulations for the three harvest values.

# %% [markdown]
# ## Problem 5 — Gompertz comparison
#
# Compare the logistic and Gompertz models with $K=1000$, $P(0)=50$, and $r=0.25$.
#
# 1. Plot both models.
# 2. Estimate when each reaches $K/2$.
# 3. Explain one visible difference.

# %% [markdown]
# ## Problem 6 — Chemical reaction
#
# A reaction is modeled by
#
# $$
# X'=0.003(50-X)(80-X),
# \qquad
# X(0)=0.
# $$
#
# 1. Identify the limiting reactant amount.
# 2. Simulate the reaction.
# 3. Estimate when $X=40$.
# 4. Explain why a computed value $X>50$ would be physically invalid.

# %% [markdown]
# ## Reflection
#
# What additional biological or chemical mechanism would you add to one of these models? Write the modified differential equation or explain the new rate term.
