# %% [markdown]
# # Homework 10 — Section 3.1
# ## Linear Models
#
# **Student notebook**
#
# For every problem, define the state variable, give units, state assumptions, formulate the IVP, and interpret the solution.

# %% [markdown]
# > **Student homework notebook — Section 3.1**
# >
# > Work the analytical parts before running code. Code cells marked `TODO` are intentionally incomplete for you to finish.
# > This repository contains **no homework solution notebooks**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.integrate import solve_ivp
from scipy.optimize import brentq
from matplotlib.patches import Rectangle, FancyArrowPatch, Circle
from IPython.display import display, Markdown

try:
    from ipywidgets import interact, FloatSlider, IntSlider, Dropdown
    WIDGETS_AVAILABLE = True
except ImportError:
    WIDGETS_AVAILABLE = False

plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["axes.grid"] = True
np.set_printoptions(precision=5, suppress=True)

def safe_solve(rhs, t_span, y0, points=700, **kwargs):
    t_eval = np.linspace(t_span[0], t_span[1], points)
    return solve_ivp(rhs, t_span, y0, t_eval=t_eval, **kwargs)

print("Notebook ready.")
print("Interactive widgets available:", WIDGETS_AVAILABLE)

# %% [markdown]
# ## Problem 1 — Bacterial growth
#
# A culture begins with 600 bacteria. After 3 hours, 960 bacteria are observed.
#
# 1. Estimate the growth constant.
# 2. Find the doubling time.
# 3. Predict the population after 8 hours.
# 4. Plot the model.

# %%
# TODO: calculate k, doubling time, and P(8), then plot.

# %% [markdown]
# ## Problem 2 — Radioactive decay
#
# A sample loses 18% of its mass in 40 days.
#
# 1. Estimate the decay constant.
# 2. Find the half-life.
# 3. Determine when 10% of the original sample remains.

# %% [markdown]
# ## Problem 3 — Cooling
#
# Soup at $85^\circ\text{C}$ is placed in a $20^\circ\text{C}$ room. After 5 minutes it is $65^\circ\text{C}$.
#
# 1. Determine the cooling parameter.
# 2. Predict the temperature after 15 minutes.
# 3. Find when the soup is within $2^\circ\text{C}$ of room temperature.
# 4. Explain why the model does not give a finite time at which $T=20$ exactly.

# %% [markdown]
# ## Problem 4 — Constant-volume mixing
#
# A 120-L tank initially contains 24 g of salt. Brine containing 0.8 g/L enters at 3 L/min, and mixture leaves at 3 L/min.
#
# 1. Construct the IVP for $A(t)$.
# 2. Find the equilibrium amount.
# 3. Solve analytically.
# 4. Simulate for 150 minutes and compare the numerical and exact solutions.

# %%
# TODO: define the RHS, exact solution, and plot both.

# %% [markdown]
# ## Problem 5 — Variable-volume tank
#
# A 100-L tank initially contains 50 g of salt. Brine containing 2 g/L enters at 5 L/min, while mixture leaves at 3 L/min. The tank capacity is 220 L.
#
# 1. Write $V(t)$.
# 2. Construct the IVP.
# 3. Determine the overflow time.
# 4. Numerically simulate only over the physically valid interval.
# 5. Explain what happens to the salt concentration as overflow approaches.

# %% [markdown]
# ## Problem 6 — LR circuit
#
# An LR circuit has $L=0.5$ H, $R=8$ ohms, constant voltage $E_0=16$ V, and $i(0)=0$.
#
# 1. Write the IVP.
# 2. Find the current.
# 3. Find the steady-state current.
# 4. Find the time constant.
# 5. Determine when the current reaches 95% of steady state.

# %% [markdown]
# ## Reflection
#
# Give one modeling assumption from cooling, mixing, or circuits that could fail in a real experiment. Describe how that failure might change the differential equation.
