# %% [markdown]
# # Homework 12 — Section 3.3
# ## Modeling with Systems of First-Order Differential Equations

# %% [markdown]
# > **Student homework notebook — Section 3.3**
# >
# > Work the analytical parts before running code. Code cells marked `TODO` are intentionally incomplete for you to finish.
# > This repository contains **no homework solution notebooks**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.integrate import solve_ivp
from scipy.optimize import brentq
from matplotlib.patches import Rectangle, FancyArrowPatch, Circle
from IPython.display import display, Markdown

try:
    from ipywidgets import interact, FloatSlider, IntSlider, Dropdown
    WIDGETS_AVAILABLE = True
except ImportError:
    WIDGETS_AVAILABLE = False

plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["axes.grid"] = True
np.set_printoptions(precision=5, suppress=True)

def safe_solve(rhs, t_span, y0, points=700, **kwargs):
    t_eval = np.linspace(t_span[0], t_span[1], points)
    return solve_ivp(rhs, t_span, y0, t_eval=t_eval, **kwargs)

print("Notebook ready.")
print("Interactive widgets available:", WIDGETS_AVAILABLE)

# %% [markdown]
# ## Problem 1 — Linear or nonlinear?
#
# Classify each system as linear or nonlinear.
#
# 1.
# $$
# x'=2x-y+t,\qquad y'=x+3y
# $$
#
# 2.
# $$
# x'=x(1-y),\qquad y'=y(x-2)
# $$
#
# 3.
# $$
# x'=-4x+2y,\qquad y'=x^2-y
# $$

# %% [markdown]
# ## Problem 2 — Radioactive decay chain
#
# A parent substance decays to a daughter at rate $k_1=0.15$, and the daughter decays to a stable product at rate $k_2=0.08$.
#
# Initially,
#
# $$
# X_1(0)=120,\qquad X_2(0)=0,\qquad X_3(0)=0.
# $$
#
# 1. Write the system.
# 2. Simulate for 100 time units.
# 3. Estimate when the daughter amount is largest.
# 4. Verify total-amount conservation numerically.

# %%
# TODO: define and simulate the decay chain.

# %% [markdown]
# ## Problem 3 — Coupled tanks
#
# Two 80-L tanks exchange liquid. Tank 1 sends 5 L/min to Tank 2, and Tank 2 sends 2 L/min to Tank 1. External flows keep each tank volume constant.
#
# Construct a closed two-state model under the following balanced external flows:
#
# - Tank 1 also receives 3 L/min of pure water.
# - Tank 2 loses 3 L/min to the environment.
#
# Initially, Tank 1 contains 60 g of salt and Tank 2 contains 10 g.
#
# 1. Derive the system.
# 2. Simulate it.
# 3. Determine whether total salt is conserved.
# 4. Explain the long-term behavior.

# %% [markdown]
# ## Problem 4 — Predator–prey equilibria
#
# For
#
# $$
# x'=0.8x-0.04xy,
# $$
#
# $$
# y'=0.02xy-0.6y,
# $$
#
# 1. find both equilibria;
# 2. simulate from $(x_0,y_0)=(40,10)$;
# 3. plot time series and the phase trajectory;
# 4. identify which population peaks first;
# 5. evaluate the Lotka–Volterra first integral numerically.

# %%
# TODO: simulate and plot.

# %% [markdown]
# ## Problem 5 — Verify the first integral symbolically
#
# For
#
# $$
# x'=\alpha x-\beta xy,
# \qquad
# y'=\delta xy-\gamma y,
# $$
#
# verify that
#
# $$
# H(x,y)=\delta x-\gamma\ln x+\beta y-\alpha\ln y
# $$
#
# satisfies $dH/dt=0$ along solutions.

# %% [markdown]
# <details>
# <summary><strong>Hint</strong></summary>
#
# Use $dH/dt=H_xx'+H_yy'$ and simplify.
#
# </details>

# %% [markdown]
# ## Problem 6 — Competition outcomes
#
# Use
#
# $$
# x'=x\left(1-\frac{x+a_{12}y}{100}\right),
# $$
#
# $$
# y'=0.8y\left(1-\frac{y+a_{21}x}{100}\right).
# $$
#
# Simulate and interpret:
#
# 1. $a_{12}=a_{21}=0.5$;
# 2. $a_{12}=1.5$, $a_{21}=0.5$;
# 3. $a_{12}=0.5$, $a_{21}=1.5$;
# 4. $a_{12}=a_{21}=1.5$ using two different initial conditions.

# %% [markdown]
# ## Reflection
#
# Choose one system model and list two assumptions that are probably unrealistic. Describe one modification and how it changes the system.
