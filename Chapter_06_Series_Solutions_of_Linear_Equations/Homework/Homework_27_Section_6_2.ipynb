# %% [markdown]
# # Homework 27 — Section 6.2
# ## Solutions About Ordinary Points

# %% [markdown]
# > **Student homework notebook — Section 6.2**
# >
# > Work the analytical parts before running code. Code cells marked `TODO` are intentionally incomplete for you to finish.
# > This repository contains **no homework solution notebooks**.

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.integrate import solve_ivp, quad
from scipy.special import jv, yv, iv, kv, eval_legendre, jn_zeros
from IPython.display import display, Markdown
try:
    from ipywidgets import interact, FloatSlider, IntSlider, Dropdown
    WIDGETS_AVAILABLE = True
except ImportError:
    WIDGETS_AVAILABLE = False
plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["axes.grid"] = True
np.set_printoptions(precision=6, suppress=True)
def polynomial_value(coefficients, x):
    x = np.asarray(x, dtype=float)
    total = np.zeros_like(x)
    for n, c in enumerate(coefficients):
        total += c*x**n
    return total
print("Notebook ready.")
print("Interactive widgets available:", WIDGETS_AVAILABLE)

# %% [markdown]
# ## Problem 1
# List real singular points and determine whether $0$ is ordinary:
# 1. $(1+x^2)y''+xy'+y=0$
# 2. $x(x-2)y''+3y'+y=0$
# 3. $(4-x^2)y''+xy=0$

# %% [markdown]
# ## Problem 2
# For $(x^2-6x+13)y''+y=0$, find the guaranteed radius centered at $0$ and at $-2$.

# %% [markdown]
# ## Problem 3
# Derive the recurrence for
# $$
# y''+xy'+2y=0.
# $$

# %% [markdown]
# ## Problem 4
# Compute coefficients through $x^{10}$ for $(c_0,c_1)=(1,0)$ and $(0,1)$, then plot.

# %%
# TODO: generate coefficient arrays and plot.

# %% [markdown]
# ## Problem 5
# Approximate
# $$
# y''-xy=0,\quad y(0)=2,\quad y'(0)=-1
# $$
# with a degree-15 series and compare with `solve_ivp` on $[-2,2]$.

# %% [markdown]
# ## Reflection
# Why do two arbitrary coefficients remain in a second-order power-series solution?
