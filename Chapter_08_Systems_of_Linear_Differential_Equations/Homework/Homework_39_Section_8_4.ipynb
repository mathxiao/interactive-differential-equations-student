# %% [markdown]
# # Homework 39 — Section 8.4
# ## Matrix Exponential

# %% [markdown]
# > **Student homework notebook — Section 8.4**
# >
# > Work the analytical parts before running code. Code cells marked `TODO` are intentionally incomplete for you to finish.
# > This repository contains **no homework solution notebooks**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.integrate import solve_ivp, quad_vec
from scipy.linalg import expm, eig
from IPython.display import display, Markdown

try:
    from ipywidgets import interact, FloatSlider, IntSlider, Dropdown
    WIDGETS_AVAILABLE = True
except ImportError:
    WIDGETS_AVAILABLE = False

plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["axes.grid"] = True
np.set_printoptions(precision=6, suppress=True)

def solve_linear_system(A, x0, t_span=(0, 10), points=1000, forcing=None):
    A = np.asarray(A, dtype=float)
    x0 = np.asarray(x0, dtype=float)
    t_eval = np.linspace(t_span[0], t_span[1], points)
    if forcing is None:
        def rhs(t, x): return A @ x
    else:
        def rhs(t, x): return A @ x + np.asarray(forcing(t), dtype=float)
    return solve_ivp(rhs, t_span, x0, t_eval=t_eval, rtol=1e-9, atol=1e-11)

print("Notebook ready.")
print("Interactive widgets available:", WIDGETS_AVAILABLE)

# %% [markdown]
# ## Problem 1
# Use the series definition to compute $e^{At}$ when
# $$
# A=\begin{pmatrix}2&0\\0&-3\end{pmatrix}.
# $$

# %% [markdown]
# ## Problem 2
# Show that if $A^2=0$, then
# $$
# e^{At}=I+At.
# $$

# %% [markdown]
# ## Problem 3
# Compute $e^{At}$ by diagonalization for
# $$
# A=\begin{pmatrix}2&1\\1&2\end{pmatrix}.
# $$

# %% [markdown]
# ## Problem 4
# Compute $e^{At}$ for
# $$
# A=\begin{pmatrix}-1&1\\0&-1\end{pmatrix}.
# $$

# %% [markdown]
# ## Problem 5
# Numerically verify
# $$
# e^{A(t+s)}=e^{At}e^{As}
# $$
# for
# $$
# A=\begin{pmatrix}0&-2\\2&0\end{pmatrix},
# \quad t=0.7,\quad s=1.1.
# $$

# %% [markdown]
# ## Problem 6
# Use the matrix exponential formula to solve
# $$
# \mathbf X'=
# \begin{pmatrix}-1&0\\0&-2\end{pmatrix}\mathbf X+
# \begin{pmatrix}1\\e^{-t}\end{pmatrix},
# \quad
# \mathbf X(0)=\begin{pmatrix}0\\1\end{pmatrix}.
# $$

# %%
# TODO: evaluate the transition term and the forcing integral.

# %% [markdown]
# ## Reflection
# Why is $e^{At}$ the natural analogue of the scalar exponential solution $e^{at}$?
