# %% [markdown]
# # Homework 38 — Section 8.3
# ## Nonhomogeneous Linear Systems

# %% [markdown]
# > **Student homework notebook — Section 8.3**
# >
# > Work the analytical parts before running code. Code cells marked `TODO` are intentionally incomplete for you to finish.
# > This repository contains **no homework solution notebooks**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.integrate import solve_ivp, quad_vec
from scipy.linalg import expm, eig
from IPython.display import display, Markdown

try:
    from ipywidgets import interact, FloatSlider, IntSlider, Dropdown
    WIDGETS_AVAILABLE = True
except ImportError:
    WIDGETS_AVAILABLE = False

plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["axes.grid"] = True
np.set_printoptions(precision=6, suppress=True)

def solve_linear_system(A, x0, t_span=(0, 10), points=1000, forcing=None):
    A = np.asarray(A, dtype=float)
    x0 = np.asarray(x0, dtype=float)
    t_eval = np.linspace(t_span[0], t_span[1], points)
    if forcing is None:
        def rhs(t, x): return A @ x
    else:
        def rhs(t, x): return A @ x + np.asarray(forcing(t), dtype=float)
    return solve_ivp(rhs, t_span, x0, t_eval=t_eval, rtol=1e-9, atol=1e-11)

print("Notebook ready.")
print("Interactive widgets available:", WIDGETS_AVAILABLE)

# %% [markdown]
# ## Problem 1
# Find a constant particular solution for
# $$
# \mathbf X'=
# \begin{pmatrix}-1&2\\0&-3\end{pmatrix}\mathbf X+
# \begin{pmatrix}5\\6\end{pmatrix}.
# $$

# %% [markdown]
# ## Problem 2
# Determine a suitable trial form for a particular solution when
# $$
# \mathbf F(t)=
# \begin{pmatrix}
# t^2+e^t\\
# \sin2t
# \end{pmatrix}.
# $$

# %% [markdown]
# ## Problem 3
# Solve by undetermined coefficients:
# $$
# \mathbf X'=
# \begin{pmatrix}-1&0\\0&-2\end{pmatrix}\mathbf X+
# \begin{pmatrix}t\\1\end{pmatrix}.
# $$

# %% [markdown]
# ## Problem 4
# Explain why forcing $e^{2t}(1,0)^T$ is resonant for
# $$
# A=\begin{pmatrix}2&0\\0&-1\end{pmatrix}.
# $$
# Find a particular solution.

# %% [markdown]
# ## Problem 5
# Verify that $\Phi(t)=e^{At}$ is a fundamental matrix for
# $$
# A=\begin{pmatrix}0&-1\\1&0\end{pmatrix}.
# $$

# %% [markdown]
# ## Problem 6
# Use the variation-of-constants formula to solve numerically
# $$
# \mathbf X'=
# \begin{pmatrix}-1&1\\-1&-1\end{pmatrix}\mathbf X+
# \begin{pmatrix}\cos t\\0\end{pmatrix},
# \quad
# \mathbf X(0)=\begin{pmatrix}1\\0\end{pmatrix}.
# $$
# Compare with `solve_ivp`.

# %%
# TODO: compute the integral formula and numerical IVP.

# %% [markdown]
# ## Reflection
# Compare the strengths and limitations of undetermined coefficients and variation of parameters.
