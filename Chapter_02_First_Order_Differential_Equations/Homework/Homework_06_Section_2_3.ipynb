# %% [markdown]
# # Homework 6 — Section 2.3
# ## Linear First-Order Equations

# %% [markdown]
# > **Student homework notebook — Section 2.3**
# >
# > Work the analytical parts before running code. Code cells marked `TODO` are intentionally incomplete for you to finish.
# > This repository contains **no homework solution notebooks**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.integrate import solve_ivp, quad
from scipy.special import erf
from IPython.display import display, Markdown

try:
    from ipywidgets import interact, FloatSlider, IntSlider, Dropdown
    WIDGETS_AVAILABLE = True
except ImportError:
    WIDGETS_AVAILABLE = False

plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["axes.grid"] = True
np.set_printoptions(precision=5, suppress=True)

def slope_field(f, xlim=(-3, 3), ylim=(-3, 3), density=21, title=None):
    x = np.linspace(*xlim, density)
    y = np.linspace(*ylim, density)
    X, Y = np.meshgrid(x, y)
    S = np.asarray(f(X, Y), dtype=float)
    S = np.nan_to_num(S, nan=0.0, posinf=20.0, neginf=-20.0)
    U = np.ones_like(S)
    length = np.sqrt(U**2 + S**2)
    plt.quiver(X, Y, U/length, S/length, angles="xy", pivot="mid")
    plt.xlim(*xlim)
    plt.ylim(*ylim)
    plt.xlabel("x")
    plt.ylabel("y")
    if title:
        plt.title(title)

def euler_method(f, x0, y0, h, n_steps):
    xs = np.empty(n_steps + 1)
    ys = np.empty(n_steps + 1)
    xs[0], ys[0] = x0, y0
    for n in range(n_steps):
        ys[n+1] = ys[n] + h*f(xs[n], ys[n])
        xs[n+1] = xs[n] + h
    return xs, ys

print("Notebook ready.")
print("Interactive widgets available:", WIDGETS_AVAILABLE)

# %% [markdown]
# ## Problem 1 — Integrating factor
#
# Solve
#
# $$
# y'+3y=2x,\qquad y(0)=1.
# $$
#
# Identify $P(x)$, $Q(x)$, and $\mu(x)$ before solving.

# %% [markdown]
# ## Problem 2 — Nonstandard form
#
# Solve
#
# $$
# (x+2)y'+y=x^2,\qquad y(0)=3.
# $$
#
# State the largest interval containing $0$ on which the solution is valid.

# %% [markdown]
# <details>
# <summary><strong>Hint</strong></summary>
#
# Divide by $x+2$ first. The integrating factor simplifies because $\int 1/(x+2)\,dx=\ln|x+2|$.
#
# </details>

# %% [markdown]
# ## Problem 3 — Singular point
#
# Find the general solution of
#
# $$
# xy'+y=x^2.
# $$
#
# Discuss the intervals on which the standard linear theory applies.

# %% [markdown]
# ## Problem 4 — Piecewise forcing
#
# Solve numerically and analytically
#
# $$
# y'+2y=f(t),\qquad y(0)=0,
# $$
#
# where
#
# $$
# f(t)=
# \begin{cases}
# 0,&0\le t<1,\\
# 4,&1\le t<3,\\
# 1,&t\ge3.
# \end{cases}
# $$
#
# Construct a continuous piecewise formula and plot the input and response.

# %%
t = np.linspace(0, 7, 700)

# TODO: define forcing and the continuous piecewise solution.
forcing = np.zeros_like(t)
solution = np.zeros_like(t)

plt.plot(t, forcing, linestyle="--", label="forcing")
plt.plot(t, solution, label="solution")
plt.legend()
plt.show()

# %% [markdown]
# ## Problem 5 — Error function
#
# Solve
#
# $$
# y'-2xy=1,\qquad y(0)=0
# $$
#
# using a definite integral. Express the answer using $\operatorname{erf}(x)$ and plot it.

# %% [markdown]
# ## Problem 6 — Interpretation
#
# For the family
#
# $$
# y=4x-2+Ce^{-x},
# $$
#
# find the linear differential equation it solves. Explain the roles of the particular part and the transient part.
