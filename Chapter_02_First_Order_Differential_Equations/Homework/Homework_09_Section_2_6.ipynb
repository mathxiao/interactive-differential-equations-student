# %% [markdown]
# # Homework 9 — Section 2.6
# ## Euler's Method

# %% [markdown]
# > **Student homework notebook — Section 2.6**
# >
# > Work the analytical parts before running code. Code cells marked `TODO` are intentionally incomplete for you to finish.
# > This repository contains **no homework solution notebooks**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.integrate import solve_ivp, quad
from scipy.special import erf
from IPython.display import display, Markdown

try:
    from ipywidgets import interact, FloatSlider, IntSlider, Dropdown
    WIDGETS_AVAILABLE = True
except ImportError:
    WIDGETS_AVAILABLE = False

plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["axes.grid"] = True
np.set_printoptions(precision=5, suppress=True)

def slope_field(f, xlim=(-3, 3), ylim=(-3, 3), density=21, title=None):
    x = np.linspace(*xlim, density)
    y = np.linspace(*ylim, density)
    X, Y = np.meshgrid(x, y)
    S = np.asarray(f(X, Y), dtype=float)
    S = np.nan_to_num(S, nan=0.0, posinf=20.0, neginf=-20.0)
    U = np.ones_like(S)
    length = np.sqrt(U**2 + S**2)
    plt.quiver(X, Y, U/length, S/length, angles="xy", pivot="mid")
    plt.xlim(*xlim)
    plt.ylim(*ylim)
    plt.xlabel("x")
    plt.ylabel("y")
    if title:
        plt.title(title)

def euler_method(f, x0, y0, h, n_steps):
    xs = np.empty(n_steps + 1)
    ys = np.empty(n_steps + 1)
    xs[0], ys[0] = x0, y0
    for n in range(n_steps):
        ys[n+1] = ys[n] + h*f(xs[n], ys[n])
        xs[n+1] = xs[n] + h
    return xs, ys

print("Notebook ready.")
print("Interactive widgets available:", WIDGETS_AVAILABLE)

# %% [markdown]
# ## Problem 1 — Two hand steps
#
# For
#
# $$
# y'=x-y,\qquad y(0)=2,
# $$
#
# use Euler's method with $h=0.25$ to calculate approximations at $x=0.25$ and $x=0.50$. Show the arithmetic.

# %% [markdown]
# ## Problem 2 — Implement Euler's method
#
# Complete a function that returns arrays of Euler points.

# %%
def my_euler(f, x0, y0, h, n_steps):
    # TODO: implement the recursion.
    pass

# %% [markdown]
# ## Problem 3 — Compare with the exact solution
#
# For the IVP in Problem 1, the exact solution is
#
# $$
# y=x-1+3e^{-x}.
# $$
#
# Use $h=0.5,0.25,0.125,0.0625$ to approximate $y(2)$. Make a table of endpoint errors.

# %%
def f(x, y):
    return x-y

def exact(x):
    return x-1+3*np.exp(-x)

step_sizes = [0.5, 0.25, 0.125, 0.0625]

# TODO: calculate endpoint approximations and errors.

# %% [markdown]
# ## Problem 4 — Error ratio
#
# Using the errors from Problem 3, calculate
#
# $$
# \frac{E(h)}{E(h/2)}.
# $$
#
# What value should this ratio approach for a first-order method?

# %% [markdown]
# ## Problem 5 — Stability experiment
#
# Apply Euler's method to
#
# $$
# y'=-6y,\qquad y(0)=1
# $$
#
# using $h=0.1$, $0.3$, and $0.4$ on $0\le t\le3$.
#
# 1. Derive the Euler multiplier $1-6h$.
# 2. Predict each numerical behavior before plotting.
# 3. Plot and compare with $e^{-6t}$.

# %%
# TODO: plot the exact solution and the three Euler approximations.

# %% [markdown]
# ## Problem 6 — Modeling with Euler
#
# A cooling model is
#
# $$
# T'=-0.12(T-22),\qquad T(0)=90.
# $$
#
# Use Euler's method with one-minute steps to estimate the temperature after 15 minutes. Compare with the exact solution and report absolute and percentage relative error.

# %% [markdown]
# ## Reflection
#
# Why can decreasing the step size improve accuracy while also increasing computational cost?
