# %% [markdown]
# # Homework 8 — Section 2.5
# ## Solutions by Substitution

# %% [markdown]
# > **Student homework notebook — Section 2.5**
# >
# > Work the analytical parts before running code. Code cells marked `TODO` are intentionally incomplete for you to finish.
# > This repository contains **no homework solution notebooks**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.integrate import solve_ivp, quad
from scipy.special import erf
from IPython.display import display, Markdown

try:
    from ipywidgets import interact, FloatSlider, IntSlider, Dropdown
    WIDGETS_AVAILABLE = True
except ImportError:
    WIDGETS_AVAILABLE = False

plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["axes.grid"] = True
np.set_printoptions(precision=5, suppress=True)

def slope_field(f, xlim=(-3, 3), ylim=(-3, 3), density=21, title=None):
    x = np.linspace(*xlim, density)
    y = np.linspace(*ylim, density)
    X, Y = np.meshgrid(x, y)
    S = np.asarray(f(X, Y), dtype=float)
    S = np.nan_to_num(S, nan=0.0, posinf=20.0, neginf=-20.0)
    U = np.ones_like(S)
    length = np.sqrt(U**2 + S**2)
    plt.quiver(X, Y, U/length, S/length, angles="xy", pivot="mid")
    plt.xlim(*xlim)
    plt.ylim(*ylim)
    plt.xlabel("x")
    plt.ylabel("y")
    if title:
        plt.title(title)

def euler_method(f, x0, y0, h, n_steps):
    xs = np.empty(n_steps + 1)
    ys = np.empty(n_steps + 1)
    xs[0], ys[0] = x0, y0
    for n in range(n_steps):
        ys[n+1] = ys[n] + h*f(xs[n], ys[n])
        xs[n+1] = xs[n] + h
    return xs, ys

print("Notebook ready.")
print("Interactive widgets available:", WIDGETS_AVAILABLE)

# %% [markdown]
# ## Problem 1 — Homogeneous equation
#
# Solve
#
# $$
# y'=\frac{2x+y}{x+2y}.
# $$
#
# Use $y=ux$ and give the final answer implicitly.

# %% [markdown]
# ## Problem 2 — Homogeneity test
#
# Determine whether each right-hand side can be written as a function of $y/x$.
#
# 1. $\dfrac{x^2+y^2}{xy}$
# 2. $\dfrac{x+y+1}{x-y}$
# 3. $\dfrac{x^3}{x^2y+y^3}$
# 4. $\dfrac{2x-y}{x+3y}$

# %% [markdown]
# ## Problem 3 — Bernoulli equation
#
# Solve
#
# $$
# y'-\frac{2}{x}y=x^2y^3,
# \qquad x>0.
# $$
#
# State any solution lost by dividing by a power of $y$.

# %% [markdown]
# <details>
# <summary><strong>Hint</strong></summary>
#
# Here $n=3$, so use $u=y^{-2}$.
#
# </details>

# %% [markdown]
# ## Problem 4 — Bernoulli IVP
#
# Solve
#
# $$
# y'+2y=e^x y^{1/2},
# \qquad y(0)=1.
# $$
#
# Use $u=y^{1/2}$.

# %% [markdown]
# ## Problem 5 — Linear-combination substitution
#
# Solve
#
# $$
# y'=2+(x-y)^2,
# \qquad y(0)=0.
# $$
#
# Use $u=x-y$, then plot the solution on its maximal interval.

# %%
# TODO: derive and plot the solution.

# %% [markdown]
# ## Problem 6 — Method selection
#
# For each equation, choose the most direct method and briefly justify the choice.
#
# 1. $y'=x(1+y^2)$
# 2. $y'+xy=x$
# 3. $(2xy+1)\,dx+(x^2+3y^2)\,dy=0$
# 4. $y'=(x+y)/(x-y)$
# 5. $y'+y=xy^2$
