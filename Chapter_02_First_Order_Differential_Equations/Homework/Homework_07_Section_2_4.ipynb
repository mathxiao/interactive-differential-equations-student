# %% [markdown]
# # Homework 7 — Section 2.4
# ## Exact Equations

# %% [markdown]
# > **Student homework notebook — Section 2.4**
# >
# > Work the analytical parts before running code. Code cells marked `TODO` are intentionally incomplete for you to finish.
# > This repository contains **no homework solution notebooks**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.integrate import solve_ivp, quad
from scipy.special import erf
from IPython.display import display, Markdown

try:
    from ipywidgets import interact, FloatSlider, IntSlider, Dropdown
    WIDGETS_AVAILABLE = True
except ImportError:
    WIDGETS_AVAILABLE = False

plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["axes.grid"] = True
np.set_printoptions(precision=5, suppress=True)

def slope_field(f, xlim=(-3, 3), ylim=(-3, 3), density=21, title=None):
    x = np.linspace(*xlim, density)
    y = np.linspace(*ylim, density)
    X, Y = np.meshgrid(x, y)
    S = np.asarray(f(X, Y), dtype=float)
    S = np.nan_to_num(S, nan=0.0, posinf=20.0, neginf=-20.0)
    U = np.ones_like(S)
    length = np.sqrt(U**2 + S**2)
    plt.quiver(X, Y, U/length, S/length, angles="xy", pivot="mid")
    plt.xlim(*xlim)
    plt.ylim(*ylim)
    plt.xlabel("x")
    plt.ylabel("y")
    if title:
        plt.title(title)

def euler_method(f, x0, y0, h, n_steps):
    xs = np.empty(n_steps + 1)
    ys = np.empty(n_steps + 1)
    xs[0], ys[0] = x0, y0
    for n in range(n_steps):
        ys[n+1] = ys[n] + h*f(xs[n], ys[n])
        xs[n+1] = xs[n] + h
    return xs, ys

print("Notebook ready.")
print("Interactive widgets available:", WIDGETS_AVAILABLE)

# %% [markdown]
# ## Problem 1 — Exactness test
#
# Determine whether each equation is exact.
#
# 1. $(2xy+1)\,dx+(x^2+4y^3)\,dy=0$
# 2. $(y+e^x)\,dx+(x+\cos y)\,dy=0$
# 3. $(3x^2-y)\,dx+(x+2y)\,dy=0$

# %% [markdown]
# ## Problem 2 — Solve an exact equation
#
# Solve
#
# $$
# (2xy+3)\,dx+(x^2+2y)\,dy=0.
# $$
#
# Verify your potential function with SymPy.

# %%
x, y = sp.symbols("x y", real=True)

# TODO: enter the potential F.
F = 0
display(sp.diff(F, x))
display(sp.diff(F, y))

# %% [markdown]
# ## Problem 3 — Initial-value problem
#
# Solve
#
# $$
# (3x^2+2y)\,dx+(2x+2y)\,dy=0,
# \qquad y(1)=2.
# $$
#
# Plot the corresponding level curve.

# %% [markdown]
# ## Problem 4 — Integrating factor depending on $y$
#
# Show that
#
# $$
# y\,dx+(3x-2y^2)\,dy=0
# $$
#
# is not exact. Find an integrating factor depending only on $y$, make the equation exact, and solve.

# %% [markdown]
# <details>
# <summary><strong>Hint</strong></summary>
#
# Compute $(N_x-M_y)/M$.
#
# </details>

# %% [markdown]
# ## Problem 5 — Geometric interpretation
#
# For
#
# $$
# F(x,y)=x^2+xy+y^2,
# $$
#
# 1. find the exact differential equation $dF=0$,
# 2. plot several level curves,
# 3. plot selected gradient vectors,
# 4. explain why the gradient vectors are perpendicular to the solution curves.

# %%
x_vals = np.linspace(-3, 3, 300)
y_vals = np.linspace(-3, 3, 300)
X, Y = np.meshgrid(x_vals, y_vals)

# TODO: calculate F and plot contours and gradients.

# %% [markdown]
# ## Reflection
#
# What is the conceptual difference between the integrating factor used for a linear equation and an integrating factor used to make a differential form exact?
