# %% [markdown]
# # Homework 4 — Section 2.1
# ## Direction Fields, Autonomous Equations, and Stability
#
# **Student notebook**
#
# Show sign analysis before using numerical simulation.

# %% [markdown]
# > **Student homework notebook — Section 2.1**
# >
# > Work the analytical parts before running code. Code cells marked `TODO` are intentionally incomplete for you to finish.
# > This repository contains **no homework solution notebooks**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.integrate import solve_ivp, quad
from scipy.special import erf
from IPython.display import display, Markdown

try:
    from ipywidgets import interact, FloatSlider, IntSlider, Dropdown
    WIDGETS_AVAILABLE = True
except ImportError:
    WIDGETS_AVAILABLE = False

plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["axes.grid"] = True
np.set_printoptions(precision=5, suppress=True)

def slope_field(f, xlim=(-3, 3), ylim=(-3, 3), density=21, title=None):
    x = np.linspace(*xlim, density)
    y = np.linspace(*ylim, density)
    X, Y = np.meshgrid(x, y)
    S = np.asarray(f(X, Y), dtype=float)
    S = np.nan_to_num(S, nan=0.0, posinf=20.0, neginf=-20.0)
    U = np.ones_like(S)
    length = np.sqrt(U**2 + S**2)
    plt.quiver(X, Y, U/length, S/length, angles="xy", pivot="mid")
    plt.xlim(*xlim)
    plt.ylim(*ylim)
    plt.xlabel("x")
    plt.ylabel("y")
    if title:
        plt.title(title)

def euler_method(f, x0, y0, h, n_steps):
    xs = np.empty(n_steps + 1)
    ys = np.empty(n_steps + 1)
    xs[0], ys[0] = x0, y0
    for n in range(n_steps):
        ys[n+1] = ys[n] + h*f(xs[n], ys[n])
        xs[n+1] = xs[n] + h
    return xs, ys

print("Notebook ready.")
print("Interactive widgets available:", WIDGETS_AVAILABLE)

# %% [markdown]
# ## Problem 1 — Read a direction field analytically
#
# For
#
# $$
# y'=2x-y,
# $$
#
# 1. Find the zero-slope isocline.
# 2. State where solutions increase and decrease.
# 3. Generate the direction field.
# 4. Add numerical curves through $(0,-2)$, $(0,0)$, and $(0,3)$.

# %%
def f(x, y):
    return 2*x-y

# TODO: generate the field and add the three curves.

# %% [markdown]
# ## Problem 2 — Build a phase line
#
# For
#
# $$
# y'=(y+3)(y-1)(5-y),
# $$
#
# 1. Find all equilibria.
# 2. Make a sign chart.
# 3. Draw the phase line.
# 4. Classify each equilibrium.
# 5. Predict the limit as $t\to\infty$ for initial values $y(0)=-4,0,2,7$.

# %% [markdown]
# <details>
# <summary><strong>Hint</strong></summary>
#
# Select one test value from each interval separated by the equilibria.
#
# </details>

# %% [markdown]
# ## Problem 3 — Confirm with simulation
#
# Numerically solve the four IVPs from Problem 2 on $0\le t\le8$. Explain whether the plots agree with the phase line.

# %%
def rhs(t, y):
    return [(y[0]+3)*(y[0]-1)*(5-y[0])]

# TODO: solve and plot the four initial values.

# %% [markdown]
# ## Problem 4 — Semistability
#
# Analyze
#
# $$
# y'=(y+2)^2.
# $$
#
# 1. Identify the equilibrium.
# 2. Determine the arrow direction on both sides.
# 3. Classify the equilibrium.
# 4. Simulate solutions starting at $-3$, $-1.5$, and $0$.

# %% [markdown]
# ## Problem 5 — Autonomous or not?
#
# Classify each equation as autonomous or nonautonomous.
#
# 1. $y'=y-y^3$
# 2. $y'=xy$
# 3. $P'=0.4P(1-P/800)$
# 4. $T'=-0.2(T-25)+3\sin t$
# 5. $v'=9.8-0.15v$

# %% [markdown]
# ## Problem 6 — Translation property
#
# The function
#
# $$
# y(x)=\frac{1}{1+4e^{-x}}
# $$
#
# solves $y'=y(1-y)$.
#
# 1. Construct a solution satisfying $y(3)=1/5$ using a horizontal translation.
# 2. Verify the translated solution symbolically or numerically.
# 3. Plot both solutions.

# %% [markdown]
# ## Reflection
#
# Why can an autonomous first-order solution not oscillate between two consecutive equilibrium levels?
