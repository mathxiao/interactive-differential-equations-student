# %% [markdown]
# # Homework 5 — Section 2.2
# ## Separable Equations
#
# **Student notebook**

# %% [markdown]
# > **Student homework notebook — Section 2.2**
# >
# > Work the analytical parts before running code. Code cells marked `TODO` are intentionally incomplete for you to finish.
# > This repository contains **no homework solution notebooks**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.integrate import solve_ivp, quad
from scipy.special import erf
from IPython.display import display, Markdown

try:
    from ipywidgets import interact, FloatSlider, IntSlider, Dropdown
    WIDGETS_AVAILABLE = True
except ImportError:
    WIDGETS_AVAILABLE = False

plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["axes.grid"] = True
np.set_printoptions(precision=5, suppress=True)

def slope_field(f, xlim=(-3, 3), ylim=(-3, 3), density=21, title=None):
    x = np.linspace(*xlim, density)
    y = np.linspace(*ylim, density)
    X, Y = np.meshgrid(x, y)
    S = np.asarray(f(X, Y), dtype=float)
    S = np.nan_to_num(S, nan=0.0, posinf=20.0, neginf=-20.0)
    U = np.ones_like(S)
    length = np.sqrt(U**2 + S**2)
    plt.quiver(X, Y, U/length, S/length, angles="xy", pivot="mid")
    plt.xlim(*xlim)
    plt.ylim(*ylim)
    plt.xlabel("x")
    plt.ylabel("y")
    if title:
        plt.title(title)

def euler_method(f, x0, y0, h, n_steps):
    xs = np.empty(n_steps + 1)
    ys = np.empty(n_steps + 1)
    xs[0], ys[0] = x0, y0
    for n in range(n_steps):
        ys[n+1] = ys[n] + h*f(xs[n], ys[n])
        xs[n+1] = xs[n] + h
    return xs, ys

print("Notebook ready.")
print("Interactive widgets available:", WIDGETS_AVAILABLE)

# %% [markdown]
# ## Problem 1 — Basic separation
#
# Solve
#
# $$
# y'=3x^2(1-y),\qquad y(0)=4.
# $$
#
# State the maximal interval and verify the solution symbolically.

# %%
x = sp.symbols("x", real=True)

# TODO: enter your explicit solution and compute the residual.
y = 0
residual = 0
display(sp.simplify(residual))

# %% [markdown]
# ## Problem 2 — Implicit solution
#
# Solve
#
# $$
# y\,y'=-3x,\qquad y(1)=-3.
# $$
#
# 1. Find the implicit curve.
# 2. Select the correct explicit branch.
# 3. State its maximal interval.
# 4. Plot the complete implicit curve and highlight the IVP branch.

# %% [markdown]
# ## Problem 3 — Lost solutions
#
# Solve
#
# $$
# y'=(x+1)y(y-4).
# $$
#
# List every equilibrium solution before separating variables.

# %% [markdown]
# <details>
# <summary><strong>Hint</strong></summary>
#
# The roots of the factor depending on $y$ give constant solutions.
#
# </details>

# %% [markdown]
# ## Problem 4 — Logistic model
#
# A population follows
#
# $$
# P'=0.6P\left(1-\frac{P}{1200}\right),\qquad P(0)=100.
# $$
#
# 1. Find $P(t)$.
# 2. Plot the solution for $0\le t\le20$.
# 3. Estimate when the population reaches 600.
# 4. Explain the role of 1200.

# %%
# TODO: calculate and plot the logistic solution.

# %% [markdown]
# ## Problem 5 — Integral-defined function
#
# Solve
#
# $$
# y'=\cos(x^3),\qquad y(1)=2
# $$
#
# using a definite integral. Plot the solution on $-2\le x\le2$ using numerical quadrature.

# %%
x_vals = np.linspace(-2, 2, 250)

# TODO: evaluate 2 + integral from 1 to x of cos(t^3) dt.
y_vals = np.zeros_like(x_vals)

plt.plot(x_vals, y_vals)
plt.scatter([1], [2], s=70)
plt.show()

# %% [markdown]
# ## Problem 6 — Interval awareness
#
# Solve
#
# $$
# y'=2xy^2,\qquad y(0)=1.
# $$
#
# Find the first positive $x$ where the solution becomes unbounded, and compare the exact curve with a numerical solution as the blow-up point is approached.

# %% [markdown]
# ## Reflection
#
# Why is it mathematically safer to keep a separable solution implicit until after applying the initial condition?
